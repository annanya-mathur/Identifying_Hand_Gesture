# %% [markdown]
# <a href="https://colab.research.google.com/github/annanya-mathur/Identifying_Hand_Gesture/blob/master/Thresholding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **THRESHOLDING**
# > **Thresholding is the simplest method of segmenting images. From a grayscale image, thresholding can be used to create binary images.Image is divided into pixels. For every pixel, the same threshold value is applied. If the pixel value is smaller than the threshold, it is set to 0, otherwise it is set to a maximum value.**
# > ![dia.png](data:image/png;base64,...)

# %% [markdown]
# # **TYPES OF THRESHOLDING**
#
# ![threshold.jpg](data:image/jpeg;base64,...)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as pt
from google.colab.patches import cv2_imshow

# %%
from tensorflow.keras.preprocessing import image
img=image.load_img('/content/ges.jpg')
pt.imshow(img)

# %% [markdown]
# > **Converting the image on the scale of 0-200**

# %% [markdown]
# #**The function cv2.threshold is used to apply the thresholding.**
#
#   ****
# 1.   **The first argument is the source image, which should be a grayscale image.**
# 2.   **The second argument is the threshold value which is used to classify the pixel values.**
# 3. **The third argument is the maximum value which is assigned to pixel values exceeding the threshold.**
# 4. **Fourth argument is the type of threshold**

# %%
gray=cv2.imread('/content/ges.jpg',0)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=345x228 at 0x7F0C140A47D0>

# %%
ret, thresh1=cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
cv2_imshow(thresh1)
# Out:
# <PIL.Image.Image image mode=L size=345x228 at 0x7F0C143FA890>

# %%
ret, thresh2=cv2.threshold(gray,127,255,cv2.THRESH_BINARY_INV)
cv2_imshow(thresh2)
# Out:
# <PIL.Image.Image image mode=L size=345x228 at 0x7F0C143FAAD0>

# %%
ret, thresh3=cv2.threshold(gray,127,255,cv2.THRESH_TRUNC)
cv2_imshow(thresh3)
# Out:
# <PIL.Image.Image image mode=L size=345x228 at 0x7F0C14048D50>

# %%
ret, thresh4=cv2.threshold(gray,127,255,cv2.THRESH_TOZERO)
cv2_imshow(thresh4)
# Out:
# <PIL.Image.Image image mode=L size=345x228 at 0x7F0C13FD7CD0>

# %%
ret, thresh5=cv2.threshold(gray,127,255,cv2.THRESH_TOZERO_INV)
cv2_imshow(thresh5)
# Out:
# <PIL.Image.Image image mode=L size=345x228 at 0x7F0C143FA810>

# %%
ret, thresh6=cv2.threshold(gray,127,255,cv2.THRESH_OTSU)
cv2_imshow(thresh6)
# Out:
# <PIL.Image.Image image mode=L size=345x228 at 0x7F0C14048810>
